# %% [markdown]
# # ex2_scientific1

# %% [markdown]
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N = 50$ hình tròn:
# - Tâm $c_{i} = (x_{i},y_{i})$ ngẫu nhiên với $(x_{i},y_{i}) \in [0,1]$
# - Màu sắc $color_{i}$ ngẫu nhiên với $color_{i} \in [0,1]$
# - Diện tích $area_{i} = \pi * r^{2}_{i}$ với sinh ngẫu nhiên $r_{i} \in [0,1]$

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# Tạo ngẫu nhiên hình tròn tâm (x,y)
N = 50
x      = np.random.rand(N)
y      = np.random.rand(N)
colors = np.random.rand(N)
area   = np.pi * (15 * np.random.rand(N)) ** 2
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# Kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.03, 0.99]: 10 samples [[0.64012992 0.22906514 0.39440025 0.87372453 0.02562274 0.35503567
#  0.81006814 0.19066331 0.39661908 0.10389725]]
# + y: len=50, [0.05, 0.99]: 10 samples [[0.14070934 0.12953005 0.60386435 0.32966031 0.33686657 0.78826854
#  0.13114702 0.75372668 0.77318494 0.56525083]]
# + colors: len=50, [0.01, 0.99]: 10 samples [[0.93545215 0.77411273 0.00585046 0.21565685 0.91144831 0.44815969
#  0.02028221 0.34585816 0.71543351 0.61447289]]
# + area: len=50, [0.00, 695.58]: 10 samples [[5.42955256e+00 1.76568327e+01 6.15260583e+02 4.74783415e+00
#  3.97160105e+02 1.87841387e+00 1.42174836e+01 9.95720948e+01
#  1.43708465e+02 2.22980794e-01]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
